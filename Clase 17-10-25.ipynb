# %% [markdown]
# ### Algoritmo CART (Classification and Regression Trees)

# %% [markdown]
# Las gráficas de dispersión ayuda a poder relacionar datos como la edad y el colesterol, es decir no son gráficas que dependen de una función, es decir que no tiene como tal una variable dependiente (y) y una independiente (x). En este tipo de datasets o para determinar si alguien tiene una enfermedad por ejemplo, necesitamos un experto en el tema a tratar

# %% [markdown]
# #### Indice Gini

# %% [markdown]
# Los cuadrados se usan para tener una mejor aproximación

# %% [markdown]
# ### Calidad de la partición

# %% [markdown]
# Qué tan efectiva es
# $$Calidad = \frac{mi}{m}G_{izq}+\frac{m_\alpha}{m}G_{der} $$
